# %%
# load required libraries
import urllib
from bs4 import BeautifulSoup
import pandas as pd
import re
import json
import string
import itertools

# %%
Reference:

https://github.com/tlfvincent/political_liars/blob/master/scrape_politifact.py
https://github.com/tlfvincent/political_liars/blob/master/analysis.R

# %%
# create custom functions to acquire the data
def get_page_source(page):
    '''get HTML content of page'''
    try:
        url = 'http://www.politifact.com/truth-o-meter/statements/?page={}'.format(page)
        response = urllib2.urlopen(url)
        page_source = response.read()
        soup = BeautifulSoup(page_source, "html.parser")
        return soup
    except:
        print ("Could not obtain data for page {}".format(page))
        return None

# %%
def extract_truth(table,
                  truth_meter,
                  image_source,
                  statement_text):
    '''extract statement text, image of candidate and truth of statement'''
    for truth in table:
        fact = [item['alt'] for item in truth.findAll("img")]
        images = [item['src'] for item in truth.findAll("img") if '.jpg' in item['src']]
        statement = [item.text.strip() for item in truth.findAll("a", {"class": "link"})]
        if fact[1] in truth_meter:
            truth_meter[fact[1]].append(fact[0])
            statement_text[fact[1]].append(statement[0])
        else:
            truth_meter[fact[1]] = []
            truth_meter[fact[1]].append(fact[0])
            statement_text[fact[1]] = []
            statement_text[fact[1]].append(statement[0])
            image_source[fact[1]] = images[0]
    return truth_meter, image_source, statement_text

# %%
def process_page_data(soup,
                      truth_meter,
                      image_source,
                      statement_text):
    try:
        table = soup.findAll("div", {'class': 'scoretable__item'})
        truth_meter, image_source, statement_text = extract_truth(table,
                                                                  truth_meter,
                                                                  image_source,
                                                                  statement_text)
        return truth_meter, image_source, statement_text
    except:
        return truth_meter, image_source, statement_text

# %%
def main():
    truth_meter, image_source, statement_text = {}, {}, {}
    for page in range(1, 198):
        print (page)
        soup = get_page_source(page)
        if soup is not None:
            truth_meter, image_source, statement_text = process_page_data(soup,
                                                                          truth_meter,
                                                                          image_source,
                                                                          statement_text)

    # process statement strings for R
    statement_text_processed = {}
    for k, val in statement_text.items():
        val_no_punctuation = ["".join(l for l in sent if l not in string.punctuation) \
                              for sent in val]
        val_lower = [sent.lower() for sent in val_no_punctuation]
        if len(val_lower) > 1:
            val_tokenized = ' '.join(val_lower).split(' ')
        else:
            val_tokenized = val_lower[0].split(' ')
        statement_text_processed[k] = val_tokenized

    with open('./data/politifact_statements.txt', 'w') as outfile:
        json.dump(truth_meter, outfile)

    with open('./data/politifact_statements_text.txt', 'w') as outfile:
        json.dump(statement_text_processed, outfile)

    df = pd.DataFrame.from_dict(image_source.items())
    df.to_csv('./data/politifact_image_source.csv', index=False, encoding='utf-8')

# %%
# Show time
if __name__ == '__main__':
    main()
# Out:
# 1
# Could not obtain data for page 1
# 2
# Could not obtain data for page 2
# 3
# Could not obtain data for page 3
# 4
# Could not obtain data for page 4
# 5
# Could not obtain data for page 5
# 6
# Could not obtain data for page 6
# 7
# Could not obtain data for page 7
# 8
# Could not obtain data for page 8
# 9
# Could not obtain data for page 9
# 10
# Could not obtain data for page 10
# 11
# Could not obtain data for page 11
# 12
# Could not obtain data for page 12
# 13
# Could not obtain data for page 13
# 14
# Could not obtain data for page 14
# 15
# Could not obtain data for page 15
# 16
# Could not obtain data for page 16
# 17
# Could not obtain data for page 17
# 18
# Could not obtain data for page 18
# 19
# Could not obtain data for page 19
# 20
# Could not obtain data for page 20
# 21
# Could not obtain data for page 21
# 22
# Could not obtain data for page 22
# 23
# Could not obtain data for page 23
# 24
# Could not obtain data for page 24
# 25
# Could not obtain data for page 25
# 26
# Could not obtain data for page 26
# 27
# Could not obtain data for page 27
# 28
# Could not obtain data for page 28
# 29
# Could not obtain data for page 29
# 30
# Could not obtain data for page 30
# 31
# Could not obtain data for page 31
# 32
# Could not obtain data for page 32
# 33
# Could not obtain data for page 33
# 34
# Could not obtain data for page 34
# 35
# Could not obtain data for page 35
# 36
# Could not obtain data for page 36
# 37
# Could not obtain data for page 37
# 38
# Could not obtain data for page 38
# 39
# Could not obtain data for page 39
# 40
# Could not obtain data for page 40
# 41
# Could not obtain data for page 41
# 42
# Could not obtain data for page 42
# 43
# Could not obtain data for page 43
# 44
# Could not obtain data for page 44
# 45
# Could not obtain data for page 45
# 46
# Could not obtain data for page 46
# 47
# Could not obtain data for page 47
# 48
# Could not obtain data for page 48
# 49
# Could not obtain data for page 49
# 50
# Could not obtain data for page 50
# 51
# Could not obtain data for page 51
# 52
# Could not obtain data for page 52
# 53
# Could not obtain data for page 53
# 54
# Could not obtain data for page 54
# 55
# Could not obtain data for page 55
# 56
# Could not obtain data for page 56
# 57
# Could not obtain data for page 57
# 58
# Could not obtain data for page 58
# 59
# Could not obtain data for page 59
# 60
# Could not obtain data for page 60
# 61
# Could not obtain data for page 61
# 62
# Could not obtain data for page 62
# 63
# Could not obtain data for page 63
# 64
# Could not obtain data for page 64
# 65
# Could not obtain data for page 65
# 66
# Could not obtain data for page 66
# 67
# Could not obtain data for page 67
# 68
# Could not obtain data for page 68
# 69
# Could not obtain data for page 69
# 70
# Could not obtain data for page 70
# 71
# Could not obtain data for page 71
# 72
# Could not obtain data for page 72
# 73
# Could not obtain data for page 73
# 74
# Could not obtain data for page 74
# 75
# Could not obtain data for page 75
# 76
# Could not obtain data for page 76
# 77
# Could not obtain data for page 77
# 78
# Could not obtain data for page 78
# 79
# Could not obtain data for page 79
# 80
# Could not obtain data for page 80
# 81
# Could not obtain data for page 81
# 82
# Could not obtain data for page 82
# 83
# Could not obtain data for page 83
# 84
# Could not obtain data for page 84
# 85
# Could not obtain data for page 85
# 86
# Could not obtain data for page 86
# 87
# Could not obtain data for page 87
# 88
# Could not obtain data for page 88
# 89
# Could not obtain data for page 89
# 90
# Could not obtain data for page 90
# 91
# Could not obtain data for page 91
# 92
# Could not obtain data for page 92
# 93
# Could not obtain data for page 93
# 94
# Could not obtain data for page 94
# 95
# Could not obtain data for page 95
# 96
# Could not obtain data for page 96
# 97
# Could not obtain data for page 97
# 98
# Could not obtain data for page 98
# 99
# Could not obtain data for page 99
# 100
# Could not obtain data for page 100
# 101
# Could not obtain data for page 101
# 102
# Could not obtain data for page 102
# 103
# Could not obtain data for page 103
# 104
# Could not obtain data for page 104
# 105
# Could not obtain data for page 105
# 106
# Could not obtain data for page 106
# 107
# Could not obtain data for page 107
# 108
# Could not obtain data for page 108
# 109
# Could not obtain data for page 109
# 110
# Could not obtain data for page 110
# 111
# Could not obtain data for page 111
# 112
# Could not obtain data for page 112
# 113
# Could not obtain data for page 113
# 114
# Could not obtain data for page 114
# 115
# Could not obtain data for page 115
# 116
# Could not obtain data for page 116
# 117
# Could not obtain data for page 117
# 118
# Could not obtain data for page 118
# 119
# Could not obtain data for page 119
# 120
# Could not obtain data for page 120
# 121
# Could not obtain data for page 121
# 122
# Could not obtain data for page 122
# 123
# Could not obtain data for page 123
# 124
# Could not obtain data for page 124
# 125
# Could not obtain data for page 125
# 126
# Could not obtain data for page 126
# 127
# Could not obtain data for page 127
# 128
# Could not obtain data for page 128
# 129
# Could not obtain data for page 129
# 130
# Could not obtain data for page 130
# 131
# Could not obtain data for page 131
# 132
# Could not obtain data for page 132
# 133
# Could not obtain data for page 133
# 134
# Could not obtain data for page 134
# 135
# Could not obtain data for page 135
# 136
# Could not obtain data for page 136
# 137
# Could not obtain data for page 137
# 138
# Could not obtain data for page 138
# 139
# Could not obtain data for page 139
# 140
# Could not obtain data for page 140
# 141
# Could not obtain data for page 141
# 142
# Could not obtain data for page 142
# 143
# Could not obtain data for page 143
# 144
# Could not obtain data for page 144
# 145
# Could not obtain data for page 145
# 146
# Could not obtain data for page 146
# 147
# Could not obtain data for page 147
# 148
# Could not obtain data for page 148
# 149
# Could not obtain data for page 149
# 150
# Could not obtain data for page 150
# 151
# Could not obtain data for page 151
# 152
# Could not obtain data for page 152
# 153
# Could not obtain data for page 153
# 154
# Could not obtain data for page 154
# 155
# Could not obtain data for page 155
# 156
# Could not obtain data for page 156
# 157
# Could not obtain data for page 157
# 158
# Could not obtain data for page 158
# 159
# Could not obtain data for page 159
# 160
# Could not obtain data for page 160
# 161
# Could not obtain data for page 161
# 162
# Could not obtain data for page 162
# 163
# Could not obtain data for page 163
# 164
# Could not obtain data for page 164
# 165
# Could not obtain data for page 165
# 166
# Could not obtain data for page 166
# 167
# Could not obtain data for page 167
# 168
# Could not obtain data for page 168
# 169
# Could not obtain data for page 169
# 170
# Could not obtain data for page 170
# 171
# Could not obtain data for page 171
# 172
# Could not obtain data for page 172
# 173
# Could not obtain data for page 173
# 174
# Could not obtain data for page 174
# 175
# Could not obtain data for page 175
# 176
# Could not obtain data for page 176
# 177
# Could not obtain data for page 177
# 178
# Could not obtain data for page 178
# 179
# Could not obtain data for page 179
# 180
# Could not obtain data for page 180
# 181
# Could not obtain data for page 181
# 182
# Could not obtain data for page 182
# 183
# Could not obtain data for page 183
# 184
# Could not obtain data for page 184
# 185
# Could not obtain data for page 185
# 186
# Could not obtain data for page 186
# 187
# Could not obtain data for page 187
# 188
# Could not obtain data for page 188
# 189
# Could not obtain data for page 189
# 190
# Could not obtain data for page 190
# 191
# Could not obtain data for page 191
# 192
# Could not obtain data for page 192
# 193
# Could not obtain data for page 193
# 194
# Could not obtain data for page 194
# 195
# Could not obtain data for page 195
# 196
# Could not obtain data for page 196
# 197
# Could not obtain data for page 197
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-ebf7806e4be0> in <module>
#       1 # Show time
#       2 if __name__ == '__main__':
# ----> 3     main()
#
# <ipython-input-8-d6716f41700d> in main()
#      22         statement_text_processed[k] = val_tokenized
#      23
# ---> 24     with open('./data/politifact_statements.txt', 'w') as outfile:
#      25         json.dump(truth_meter, outfile)
#      26
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/politifact_statements.txt'
