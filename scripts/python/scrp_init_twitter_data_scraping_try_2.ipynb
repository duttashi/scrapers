# %% [markdown]
# Using the `twint` library for twitter data scraping

# %%
# install the library 
# pip3 install twint
# load the library
import twint

# %%
# Set up TWINT config
c = twint.Config()
c.Search("KTM")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-bd1482020fb4> in <module>()
#       1 # Set up TWINT config
#       2 c = twint.Config()
# ----> 3 c.Search("KTM")
#
# TypeError: 'NoneType' object is not callable

# %%
# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-a70856039f52> in <module>()
#       1 # Run
# ----> 2 twint.run.Search(c)
#
# ~\Miniconda3\lib\site-packages\twint\run.py in Search(config)
#     135 def Search(config):
#     136     config.TwitterSearch = True
# --> 137     run(config)
#
# ~\Miniconda3\lib\site-packages\twint\run.py in run(config)
#     115
#     116 def run(config):
# --> 117     get_event_loop().run_until_complete(Twint(config).main())
#     118
#     119 def Favorites(config):
#
# ~\Miniconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# ...
