# %% [markdown]
# Objective: Create a basic crawler that can extract all the links in a page and then browse to each of the extracted links.
#
#     Status: Work in progress
#
#     Script create date: 25/10/2018

# %%
# import the require libraries
from bs4 import BeautifulSoup
import requests

# %%
url = input("Enter a website to extract the URL's from: ")

r  = requests.get("http://" +url)
data = r.text
# create the soup
soup = BeautifulSoup(data)

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# Enter a website to extract the URL's from: mbg.com.my
# /
# /collections/fresh-fruits
# /collections/mbg-grape-series
# /collections/berries
# /collections/stone-fruits
# /collections/local-fruits
# /collections/citrus-fruits
# /collections/apples-and-pears
# /collections/juices
# /collections/fruit-box
# /collections/dry-products/dry8
# /collections/nuts-and-seeds
# /collections/dry-fruits
# /collections/dates
# /collections/fruit-basket
# /collections/get-well-soon-fruit-baskets
# /collections/loving-fruitbasket
# /blogs/news
# /blogs/news
# /blogs/fruit-info
# https://mbg.com.my/blogs/mbg-card-membership-info/check-your-mbg-card-point
# /pages/contact-us
# /pages/store-locator
# /
# /
# /
# /collections/fresh-fruits
# /collections/mbg-grape-series
# /collections/berries
# /collections/stone-fruits
# /collections/local-fruits
# /collections/citrus-fruits
# /collections/apples-and-pears
# /collections/juices
# /collections/fruit-box
# /collections/dry-products/dry8
# ...

# %% [markdown]
# As can be seen, there are several undesired elements like `#` or `#15316490838021`.. So, how to acquire the sub-links only?
